# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
d1=pd.read_csv("C:/Users/Rehaman shaik/Desktop/data science practice session/assisgments/simple linear regression/Salary_Data.csv")
d1
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
d1.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
d1.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
d1.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# Scatter plot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='YearsExperience', y='Salary', data=d1)
plt.title('Scatter Plot of YearsExperience vs. Salary')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
# Regression plot

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='YearsExperience', y='Salary', data=d1)
plt.title('Regression Plot of YearsExperience vs. Salary')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
sns.pairplot(d1)
# Out:
# C:\Users\Rehaman shaik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
d1["YearsExperience"].hist()
# Out:
# <Axes: >

# %%
d1["Salary"].hist()
# Out:
# <Axes: >

# %%
#assining the target vuariable

# %%
y=d1["Salary"]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x=d1[["YearsExperience"]]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
#spliting the train and test data

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y,test_size=0.30)

# %%
le=LinearRegression()
le.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=le.predict(x_test)
y_pred
# Out:
# array([ 68336.04129143,  92431.63262059,  82237.34398133,  72043.05534207,
#         40533.43591164,  56288.24562686, 123941.25205102, 114673.71692442,
#         89651.37208261])

# %%
mse=mean_squared_error(y_test, y_pred)
mse
# Out:
# 29475753.08556943

# %%
print("mean squared error:",mse.round(3))
print("ROOT MEAN SQUARE ERROR",np.sqrt(mse).round(3))
print("R2 score:",r2_score(y_test, y_pred).round(3))
# Out:
# mean squared error: 29475753.086
# ROOT MEAN SQUARE ERROR 5429.158
# R2 score: 0.96

# %%
#visualize the linear line
plt.scatter(x_test, y_test,color="Red")
plt.plot(x_test,y_pred,color="blue")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Regression Line")
plt.show()

# %%
# Apply square root transformation
x_sqrt_train, x_sqrt_test = np.sqrt(x_train), np.sqrt(x_test)
le.fit(x_sqrt_train, y_train)
y_pred_sqrt = le.predict(x_sqrt_test)
mse_sqrt = mean_squared_error(y_test, y_pred_sqrt)

# %%
# Print and visualize square root transformation
print("\nModel with Square Root Transformation:")
print("Mean Squared Error:", mse_sqrt.round(3))
print("Root Mean Squared Error:", np.sqrt(mse_sqrt).round(3))
print("R2 Score:", r2_score(y_test, y_pred_sqrt).round(3))
# Out:
# Model with Square Root Transformation:
# Mean Squared Error: 40169012.892
# Root Mean Squared Error: 6337.903
# R2 Score: 0.946

# %%
plt.scatter(x_sqrt_test, y_test, color="Red")
plt.plot(x_sqrt_test, y_pred_sqrt, color="blue")
plt.xlabel("Square Root of Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression Line with Square Root Transformation")
plt.show()

# %%
# Apply logarithmic transformation
x_log_train, x_log_test = np.log1p(x_train), np.log1p(x_test)
le.fit(x_log_train, y_train)
y_pred_log = le.predict(x_log_test)
mse_log = mean_squared_error(y_test, y_pred_log)

# %%
# Print and visualize logarithmic transformation
print("\nModel with Logarithmic Transformation:")
print("Mean Squared Error:", mse_log.round(3))
print("Root Mean Squared Error:", np.sqrt(mse_log).round(3))
print("R2 Score:", r2_score(y_test, y_pred_log).round(3))
# Out:
# Model with Logarithmic Transformation:
# Mean Squared Error: 64930307.366
# Root Mean Squared Error: 8057.934
# R2 Score: 0.912

# %%
plt.scatter(x_log_test, y_test, color="Red")
plt.plot(x_log_test, y_pred_log, color="blue")
plt.xlabel("Logarithm of Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression Line with Logarithmic Transformation")
plt.show()

# %%
# Apply exponential transformation
x_exp_train, x_exp_test = np.exp(x_train), np.exp(x_test)
le.fit(x_exp_train, y_train)
y_pred_exp = le.predict(x_exp_test)
mse_exp = mean_squared_error(y_test, y_pred_exp)

# %%
# Print and visualize exponential transformation
print("\nModel with Exponential Transformation:")
print("Mean Squared Error:", mse_exp.round(3))
print("Root Mean Squared Error:", np.sqrt(mse_exp).round(3))
print("R2 Score:", r2_score(y_test, y_pred_exp).round(3))
# Out:
# Model with Exponential Transformation:
# Mean Squared Error: 568927163.942
# Root Mean Squared Error: 23852.194
# R2 Score: 0.232

# %%
plt.scatter(x_exp_test, y_test, color="Red")
plt.plot(x_exp_test, y_pred_exp, color="blue")
plt.xlabel("Exponential of Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression Line with Exponential Transformation")
plt.show()

# %%
# Apply polynomial transformation
x_poly_train, x_poly_test = x_train**2, x_test**2
le.fit(x_poly_train, y_train)
y_pred_poly = le.predict(x_poly_test)
mse_poly = mean_squared_error(y_test, y_pred_poly)

# %%
# Print and visualize polynomial transformation
print("\nModel with Polynomial Transformation:")
print("Mean Squared Error:", mse_poly.round(3))
print("Root Mean Squared Error:", np.sqrt(mse_poly).round(3))
print("R2 Score:", r2_score(y_test, y_pred_poly).round(3))
# Out:
# Model with Polynomial Transformation:
# Mean Squared Error: 90554950.279
# Root Mean Squared Error: 9516.036
# R2 Score: 0.878

# %%
plt.scatter(x_poly_test, y_test, color="Red")
plt.plot(x_poly_test, y_pred_poly, color="blue")
plt.xlabel("Square of Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression Line with Polynomial Transformation")
plt.show()

# %%
'''The simple linear regression model performs exceptionally
well with the lowest errors and the highest R2 score, 
suggesting that a linear relationship between years of experience 
and salary is a good fit for the data.
.'''
# Out:
# 'The simple linear regression model performs exceptionally\nwell with the lowest errors and the highest R2 score, \nsuggesting that a linear relationship between years of experience \nand salary is a good fit for the data.\n.'

# %%
'''Among the transformed models, the square root transformation and
logarithmic transformation provide good fits with lower errors 
compared to the exponential transformation.
'''
# Out:
# 'Among the transformed models, the square root transformation and\nlogarithmic transformation provide good fits with lower errors \ncompared to the exponential transformation.\n'

# %%
'''The polynomial transformation introduces higher errors but still captures a
significant portion of the variance, indicating a relatively good fit'''
# Out:
# 'The polynomial transformation introduces higher errors but still captures a\nsignificant portion of the variance, indicating a relatively good fit'
